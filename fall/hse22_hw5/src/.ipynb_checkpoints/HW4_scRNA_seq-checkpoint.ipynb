# %% [markdown]
# Установка необходимых пакетов и импорт библиотек

# %%
# !pip3 install anndata
# !pip3 install scanpy
# !pip3 install matplotlib==3.1.3
# Out:
# Collecting anndata
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 172 kB/s eta 0:00:01
# Collecting natsort
#   Downloading natsort-8.2.0-py3-none-any.whl (37 kB)
# Collecting h5py>=3
#   Downloading h5py-3.7.0-cp310-cp310-macosx_10_9_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 746 kB/s eta 0:00:01
# Collecting scipy>1.4
#   Downloading scipy-1.9.3-cp310-cp310-macosx_10_9_x86_64.whl (34.3 MB)
#      |████████████████████████████████| 34.3 MB 98 kB/s eta 0:00:012
# Requirement already satisfied: numpy>=1.16.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata) (1.23.4)
# Collecting pandas>=1.1.1
#   Downloading pandas-1.5.2-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20 in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from anndata) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from packaging>=20->anndata) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from pandas>=1.1.1->anndata) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Requirement already satisfied: six>=1.5 in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.1->pandas>=1.1.1->anndata) (1.16.0)
# Installing collected packages: pytz, scipy, pandas, natsort, h5py, anndata
# Successfully installed anndata-0.8.0 h5py-3.7.0 natsort-8.2.0 pandas-1.5.2 pytz-2022.6 scipy-1.9.3
# WARNING: You are using pip version 21.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# Collecting scanpy
#   Downloading scanpy-1.9.1-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 961 kB/s eta 0:00:01
# Collecting statsmodels>=0.10.0rc2
#   Downloading statsmodels-0.13.5-cp310-cp310-macosx_10_9_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 2.2 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from scanpy) (21.3)
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.6.2-cp310-cp310-macosx_10_12_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 2.4 MB/s eta 0:00:01
# Collecting networkx>=2.3
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 372 kB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 2.4 MB/s eta 0:00:01
# Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 3.3 MB/s eta 0:00:01
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.9.3)
# Requirement already satisfied: h5py>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (3.7.0)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: natsort in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (8.2.0)
# Requirement already satisfied: numpy>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.23.4)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
# Requirement already satisfied: anndata>=0.7.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (0.8.0)
# Collecting patsy
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 2.3 MB/s eta 0:00:01
# Collecting scikit-learn>=0.22
#   Downloading scikit_learn-1.2.0-cp310-cp310-macosx_10_9_x86_64.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 1.8 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.5.2)
# Collecting numba>=0.41.0
#   Downloading numba-0.56.4-cp310-cp310-macosx_10_14_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp310-cp310-macosx_10_9_x86_64.whl (240 kB)
#      |████████████████████████████████| 240 kB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.4->scanpy) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/h1de0us/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 325 kB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#      |████████████████████████████████| 65 kB 617 kB/s eta 0:00:01
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp310-cp310-macosx_10_9_x86_64.whl (25.5 MB)
#      |███████████████████▍            | 15.5 MB 615 kB/s eta 0:00:17

# %%
import pandas as pd
from tqdm.notebook import tqdm
import seaborn as sns; sns.set_theme()
import numpy as np
import matplotlib.pyplot as plt
import anndata as ad
import scanpy as sc
from matplotlib.cm import get_cmap
from matplotlib.colors import ListedColormap

# %% [markdown]
# # Шаг 1 Загружаем файлы
# Скачиваем отдельные файлы с каунтами из датасета - https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE103967
#
# Нас интересуют файлы, соответсвующие клеткам "CD45- Epcam+ (4-6 weeks)

# %%
# Download CD45- EpCAM+ cells
gsm_list = [
            ('7017', '1395'),
            ('7018', '1396'),
            ('7019', '1398'),
            ('7020', '1458'),
            ('7021', '1459'),
            ('7022', '1539'),
            ('7023', '1540'),
            ('7024', '1541'),
            ('7025', '1542'),
            ('7026', '1544'),
            ('7027', '1545'),
            ('7028', '1546'),
            ('7029', '1646'),
            ('7030', '1647'),
            ('7031', '1648'),
            ('7032', '1649'),
            ('7033', '1751'),
            ('7034', '1753'),
            ('7035', '1792'),
            ('7036', '1793'),
            ('7037', '1795'),
]

for gsm, ab in gsm_list:
  # !wget -c -nv ### ADD YOUR CODE HERE
  # !gzip -f -d ### ADD YOUR CODE HERE
# Out:
# 2022-04-14 05:43:31 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2786nnn/GSM2786996/suppl/GSM2786996%5FAB590%2Etxt%2Egz [516392/516392] -> "AB590.txt.gz" [1]
# 2022-04-14 05:43:31 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2786nnn/GSM2786997/suppl/GSM2786997%5FAB591%2Etxt%2Egz [476603/476603] -> "AB591.txt.gz" [1]
# 2022-04-14 05:43:32 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2786nnn/GSM2786998/suppl/GSM2786998%5FAB592%2Etxt%2Egz [472708/472708] -> "AB592.txt.gz" [1]
# 2022-04-14 05:43:32 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2786nnn/GSM2786999/suppl/GSM2786999%5FAB593%2Etxt%2Egz [445501/445501] -> "AB593.txt.gz" [1]
# 2022-04-14 05:43:33 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787000/suppl/GSM2787000%5FAB594%2Etxt%2Egz [411482/411482] -> "AB594.txt.gz" [1]
# 2022-04-14 05:43:33 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787001/suppl/GSM2787001%5FAB595%2Etxt%2Egz [338492/338492] -> "AB595.txt.gz" [1]
# 2022-04-14 05:43:34 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787002/suppl/GSM2787002%5FAB674%2Etxt%2Egz [389583/389583] -> "AB674.txt.gz" [1]
# 2022-04-14 05:43:34 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787003/suppl/GSM2787003%5FAB675%2Etxt%2Egz [435090/435090] -> "AB675.txt.gz" [1]
# 2022-04-14 05:43:35 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787004/suppl/GSM2787004%5FAB676%2Etxt%2Egz [369218/369218] -> "AB676.txt.gz" [1]
# 2022-04-14 05:43:35 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787005/suppl/GSM2787005%5FAB677%2Etxt%2Egz [336512/336512] -> "AB677.txt.gz" [1]
# 2022-04-14 05:43:36 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787006/suppl/GSM2787006%5FAB730%2Etxt%2Egz [367708/367708] -> "AB730.txt.gz" [1]
# 2022-04-14 05:43:36 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787007/suppl/GSM2787007%5FAB731%2Etxt%2Egz [366893/366893] -> "AB731.txt.gz" [1]
# 2022-04-14 05:43:37 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787008/suppl/GSM2787008%5FAB752%2Etxt%2Egz [353275/353275] -> "AB752.txt.gz" [1]
# 2022-04-14 05:43:38 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787009/suppl/GSM2787009%5FAB790%2Etxt%2Egz [338150/338150] -> "AB790.txt.gz" [1]
# 2022-04-14 05:43:38 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787010/suppl/GSM2787010%5FAB832%2Etxt%2Egz [361841/361841] -> "AB832.txt.gz" [1]
# 2022-04-14 05:43:39 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787011/suppl/GSM2787011%5FAB833%2Etxt%2Egz [321534/321534] -> "AB833.txt.gz" [1]
# 2022-04-14 05:43:39 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787012/suppl/GSM2787012%5FAB834%2Etxt%2Egz [339234/339234] -> "AB834.txt.gz" [1]
# 2022-04-14 05:43:40 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787013/suppl/GSM2787013%5FAB835%2Etxt%2Egz [314966/314966] -> "AB835.txt.gz" [1]
# 2022-04-14 05:43:40 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787014/suppl/GSM2787014%5FAB837%2Etxt%2Egz [314353/314353] -> "AB837.txt.gz" [1]
# 2022-04-14 05:43:41 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787015/suppl/GSM2787015%5FAB1301%2Etxt%2Egz [443997/443997] -> "AB1301.txt.gz" [1]
# 2022-04-14 05:43:41 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787016/suppl/GSM2787016%5FAB1302%2Etxt%2Egz [432121/432121] -> "AB1302.txt.gz" [1]
# 2022-04-14 05:43:42 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787017/suppl/GSM2787017%5FAB1395%2Etxt%2Egz [484276/484276] -> "AB1395.txt.gz" [1]
# 2022-04-14 05:43:43 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787018/suppl/GSM2787018%5FAB1396%2Etxt%2Egz [398303/398303] -> "AB1396.txt.gz" [1]
# 2022-04-14 05:43:43 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787019/suppl/GSM2787019%5FAB1398%2Etxt%2Egz [490402/490402] -> "AB1398.txt.gz" [1]
# 2022-04-14 05:43:44 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787020/suppl/GSM2787020%5FAB1458%2Etxt%2Egz [393417/393417] -> "AB1458.txt.gz" [1]
# 2022-04-14 05:43:44 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787021/suppl/GSM2787021%5FAB1459%2Etxt%2Egz [482002/482002] -> "AB1459.txt.gz" [1]
# 2022-04-14 05:43:45 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787022/suppl/GSM2787022%5FAB1539%2Etxt%2Egz [348159/348159] -> "AB1539.txt.gz" [1]
# 2022-04-14 05:43:45 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787023/suppl/GSM2787023%5FAB1540%2Etxt%2Egz [341734/341734] -> "AB1540.txt.gz" [1]
# 2022-04-14 05:43:46 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787024/suppl/GSM2787024%5FAB1541%2Etxt%2Egz [368641/368641] -> "AB1541.txt.gz" [1]
# 2022-04-14 05:43:47 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787025/suppl/GSM2787025%5FAB1542%2Etxt%2Egz [389404/389404] -> "AB1542.txt.gz" [1]
# 2022-04-14 05:43:47 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787026/suppl/GSM2787026%5FAB1544%2Etxt%2Egz [315692/315692] -> "AB1544.txt.gz" [1]
# 2022-04-14 05:43:48 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787027/suppl/GSM2787027%5FAB1545%2Etxt%2Egz [335859/335859] -> "AB1545.txt.gz" [1]
# 2022-04-14 05:43:49 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787028/suppl/GSM2787028%5FAB1546%2Etxt%2Egz [337608/337608] -> "AB1546.txt.gz" [1]
# 2022-04-14 05:43:49 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787029/suppl/GSM2787029%5FAB1646%2Etxt%2Egz [508392/508392] -> "AB1646.txt.gz" [1]
# 2022-04-14 05:43:50 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787030/suppl/GSM2787030%5FAB1647%2Etxt%2Egz [499343/499343] -> "AB1647.txt.gz" [1]
# 2022-04-14 05:43:51 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787031/suppl/GSM2787031%5FAB1648%2Etxt%2Egz [431149/431149] -> "AB1648.txt.gz" [1]
# 2022-04-14 05:43:51 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787032/suppl/GSM2787032%5FAB1649%2Etxt%2Egz [461737/461737] -> "AB1649.txt.gz" [1]
# 2022-04-14 05:43:52 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787033/suppl/GSM2787033%5FAB1751%2Etxt%2Egz [321324/321324] -> "AB1751.txt.gz" [1]
# 2022-04-14 05:43:53 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787034/suppl/GSM2787034%5FAB1753%2Etxt%2Egz [354533/354533] -> "AB1753.txt.gz" [1]
# 2022-04-14 05:43:53 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787035/suppl/GSM2787035%5FAB1792%2Etxt%2Egz [419199/419199] -> "AB1792.txt.gz" [1]
# 2022-04-14 05:43:54 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787036/suppl/GSM2787036%5FAB1793%2Etxt%2Egz [375276/375276] -> "AB1793.txt.gz" [1]
# 2022-04-14 05:43:54 URL:https://ftp.ncbi.nlm.nih.gov/geo/samples/GSM2787nnn/GSM2787037/suppl/GSM2787037%5FAB1795%2Etxt%2Egz [369292/369292] -> "AB1795.txt.gz" [1]

# %% [markdown]
# # Шаг 2 Объединяем все файлы в один
# В итоге получается 1 большая матрица размером 34016 rows × 8064 columns

# %%
### ADD YOUR CODE HERE

counts
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
#                W112913  W112914  W112915  W112916  W112917  W112918  W112919  \
# 0610005C13Rik        0        0        0        0        0        0        0
# 0610007C21Rik        0        0        0        0        0        0        0
# 0610007L01Rik        0        0        0        0        1        0        0
# 0610007P08Rik        0        0        0        0        0        0        0
# 0610007P14Rik        0        0        0        0        0        0        0
# ...                ...      ...      ...      ...      ...      ...      ...
# snoZ159              0        0        0        0        0        0        0
# snoZ178              0        0        0        0        0        0        0
# snoZ39               0        0        0        0        0        0        0
# snoZ40               0        0        0        0        0        0        0
# snosnR60_Z15         0        0        0        0        0        0        0
#
#                W112920  W112921  W112922  ...  W432007  W432008  W432009  \
# 0610005C13Rik        0        0        0  ...        0        0        0
# 0610007C21Rik        0        1        1  ...        0        0        0
# 0610007L01Rik        0        0        0  ...        0        0        0
# 0610007P08Rik        0        1        0  ...        0        0        0
# 0610007P14Rik        0        1        2  ...        0        0        0
# ...                ...      ...      ...  ...      ...      ...      ...
# snoZ159              0        0        0  ...        0        0        0
# snoZ178              0        0        0  ...        0        0        0
# snoZ39               0        0        0  ...        0        0        0
# snoZ40               0        0        0  ...        0        0        0
# snosnR60_Z15         0        0        0  ...        0        0        0
#
#                W432010  W432011  W432012  W432013  W432014  W432015  W432016
# 0610005C13Rik        0        0        0        0        0        0        0
# 0610007C21Rik        0        0        0        0        0        0        0
# 0610007L01Rik        0        1        0        0        0        0        0
# 0610007P08Rik        0        0        0        0        0        0        0
# 0610007P14Rik        0        0        0        0        0        0        0
# ...                ...      ...      ...      ...      ...      ...      ...
# snoZ159              0        0        0        0        0        0        0
# snoZ178              0        0        0        0        0        0        0
# snoZ39               0        0        0        0        0        0        0
# snoZ40               0        0        0        0        0        0        0
# snosnR60_Z15         0        0        0        0        0        0        0
#
# [34016 rows x 8064 columns]

# %% [markdown]
# # Шаг 3 Экспрессия маркерных генов
#
# Сопоставляем ID-шники клеток (столцы в файлах из GEO) с ID-шниками от авторов (https://drive.google.com/file/d/1OaqaGULwMUlQ7SkdADOFMW5NrQbGtA3G/view?usp=sharing) -- они должны совпадать. Дальше работаем только с клетками из файла авторов.

# %%
# choose only cells from the provided file

### ADD YOUR CODE HERE

# %%
markers = ['Ctsl', 'Psmb11', 'Prss16', 'Ascl1', 'Sox4', 'Ccl21a', 'Apoe', 'Ly6a', 'Ccl21c', 'Aire', 'Hdc', 'Ubd', \
           'Cd52', 'Ccl20', 'Serpinb6a', 'Ly6d', 'Pigr', 'Car8', 'Lcn2', 'Trpm5', 'Avil', 'Gnb3', 'Lrmp']

# %%
# normalization (TPM (transcripts per million), FPKM (fragments per kilobase of transcript per million fragments mapped),
# normalized counts using coefficient of variation, intraclass correlation coefficient).

### ADD YOUR CODE HERE

# %%
f, ax = plt.subplots(figsize=(20, 5))
# ax = sns.heatmap(np.log(data_normalized + 1), yticklabels=True, xticklabels=False, cmap='Reds')
plt.show()

# %% [markdown]
# # Шаг 4 Визуализируем все 2341 клетки на UMAP и PCA
#
# Для этого предлагается использовать пакеты anndata (https://anndata-tutorials.readthedocs.io/en/latest/getting-started.html) и scanpy (https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html).

# %%
# counts_norm - normalized data

adata = ad.AnnData(counts_norm.T)
sc.pp.log1p(adata)
# adata.var_names = list(counts_norm.index)
# adata.obs_names = [f"Cell_{i:d}" for i in range(adata.n_obs)]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   """Entry point for launching an IPython kernel.

# %%
# add to metadata cell type provided by authors

### ADD YOUR CODE HERE

# %%
# cells_type_data - cell type provided by authors
adata.obs["cell_type"] = cells_type_data

# %%
sc.pp.pca(adata, n_comps=50)

# %%
colors = ['red', 'green', 'black', 'pink', 'orange']
cmap = get_cmap(ListedColormap(colors))

# %%
f, ax = plt.subplots(figsize=(8, 6))
sc.pl.pca(adata, color=['cell_type'], colorbar_loc=None, color_map=cmap, ax=ax)
for i, c in enumerate(colors):
  print(f'{groups[i]} - {c}')
# Out:
# mTEC-IV - red
# cTEC - green
# mTEC-II - black
# mTEC-III - pink
# mTEC-I - orange

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
sc.tl.umap(adata)
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sc.pl.umap(adata, color=['cell_type'], colorbar_loc=None, color_map=cmap, ax=ax)
plt.show()
for i, c in enumerate(colors):
  print(f'{groups[i]} - {c}')
# Out:
# mTEC-IV - red
# cTEC - green
# mTEC-II - black
# mTEC-III - pink
# mTEC-I - orange
